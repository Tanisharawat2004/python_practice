# %%
from IPython.display import display, Image

# %% [markdown]
# # Simple and Readable Syntax:
# - Python has clear and expressive syntax
# - making it easier to learn and understand.
# - Its readability helps to focus on problem-solving rather than deciphering complex code structures.

# %% [markdown]
# # Interpreted Nature of Python:
# - Python is an interpreted language, meaning that the code is executed line by line, which can make it easier to debug.

# %%
display(Image(filename='inter_comp.png'))

# %% [markdown]
# # python is open source

# %% [markdown]
# # Versatility and Applications:
# - Python is widely used in various domains such as:
#     - web development
#     - data analysis
#     - artificial intelligence
#     - scientific computing
#     - gaming
#     - GUI
#     - Data science

# %% [markdown]
# # python is high level language
# - oops(Object oriented programming language)

# %% [markdown]
# # Many standard Library are there in python
# - web application: Django,Flask
# - Data analysis: pandas,numpy,matplotlib,seaborn,plotly
# - Data Science: Scipy,Sklearn
# - Game development: Pygame
# - GuI Development: Tkinter
# - Database Access: SQLAlchemy,pymysql
# - Web scrapping- Request,beautifulsoup,selenium

# %% [markdown]
# # Community and Learning Resources:
#     - The Python community is welcoming and inclusive, with ample learning resources available online.

# %% [markdown]
# # Platform independent

# %% [markdown]
# # Dynamic Typing:
# - Python is dynamically typed, meaning you don't need to specify the data type of a variable when you declare it.
# - The interpreter figures out the type automatically during execution.

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
b=True

# %%
type(b)
# Out:
# bool

# %%
#int a
a=10

# %%
type(a)
# Out:
# int

# %%
a="pooja"
b=20

# %%
type(a)
# Out:
# str

# %% [markdown]
# # Error and Exception handling

# %% [markdown]
# # In python Indentation is important

# %%
a=10
if a>10:
    print(a)
    print("Hello")
else:
    print("bye")
    print("ok")
# Out:
# bye
# ok

# %% [markdown]
# # Versions of python

# %% [markdown]
# https://sebastianraschka.com/Articles/2014_python_2_3_key_diff.html

# %% [markdown]
# # python IDLE:file.py(Default)

# %% [markdown]
# # Editors for python:
# - pycharm
# - visual studio code
# - Jupyter notebook
# - spyder
# - sublime Text

# %% [markdown]
# Python file extension : .py
# python file extension in jupyter notebook:.ipynb
